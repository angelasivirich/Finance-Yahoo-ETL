# %%
import pandas as pd

# %%
covid_f= "covid_finance.csv"
covid_cases = pd.read_csv(covid_f)
covid_cases.to_html('covid_finance.html')
covid_cases
# Out:
#            Date  Air_Canada_open  Air_Canada_close  Air_Canada_pert_change  \
# 0    2020-08-13            16.82             17.08                    1.55
# 1    2020-08-12            16.90             16.95                    0.30
# 2    2020-08-11            16.87             16.69                   -1.07
# 3    2020-08-10            15.90             16.23                    2.08
# 4    2020-08-07            15.91             15.73                   -1.13
# ..          ...              ...               ...                     ...
# 143  2020-01-08            47.75             49.04                    2.70
# 144  2020-01-07            47.30             48.24                    1.99
# 145  2020-01-06            47.61             47.30                   -0.65
# 146  2020-01-03            48.98             48.31                   -1.37
# 147  2020-01-02            48.72             50.00                    2.63
#
#      Oil_open  Oil_close  Oil_pert_change  Gold_open  Gold_close  \
# ...
